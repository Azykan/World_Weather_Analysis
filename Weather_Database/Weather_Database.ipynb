# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
from citipy import citipy
import requests
import gmaps
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
#    if record_count == 5:
#        break    # break here
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        city_weather_cond = city_weather["weather"]
        city_weather_main = city_weather_cond[0]["main"]
        city_weather_desc = city_weather_cond[0]["description"]
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Main": city_weather_main,
                          "Current Description": city_weather_desc
                            })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gambela
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | vestmannaeyjar
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | college
# Processing Record 6 of Set 1 | praia da vitoria
# Processing Record 7 of Set 1 | ponta delgada
# Processing Record 8 of Set 1 | skagen
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | nouadhibou
# Processing Record 13 of Set 1 | puerto cabezas
# Processing Record 14 of Set 1 | zyryanka
# Processing Record 15 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 1 | hamilton
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | mandalgovi
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | zhigansk
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | norman wells
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | sur
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | abu dhabi
# Processing Record 31 of Set 1 | sorong
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | kruisfontein
# Processing Record 34 of Set 1 | erenhot
# Processing Record 35 of Set 1 | beloeil
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | cherskiy
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | kysyl-syr
# Processing Record 40 of Set 1 | rincon
# Processing Record 41 of Set 1 | morant bay
# Processing Record 42 of Set 1 | severo-kurilsk
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | ahuimanu
# Processing Record 45 of Set 1 | chapais
# Processing Record 46 of Set 1 | nioro
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | vanimo
# Processing Record 50 of Set 1 | monrovia
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | bathurst
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | san felipe
# Processing Record 6 of Set 2 | nanortalik
# Processing Record 7 of Set 2 | ballina
# Processing Record 8 of Set 2 | alibag
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | faanui
# Processing Record 12 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 13 of Set 2 | nagua
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | aklavik
# Processing Record 17 of Set 2 | bali
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 2 | pochutla
# Processing Record 22 of Set 2 | shingu
# Processing Record 23 of Set 2 | port hardy
# Processing Record 24 of Set 2 | esil
# Processing Record 25 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | kudahuvadhoo
# Processing Record 28 of Set 2 | auki
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | qasigiannguit
# Processing Record 33 of Set 2 | plettenberg bay
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | chumikan
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint-denis
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | bilibino
# Processing Record 43 of Set 2 | matsumoto
# Processing Record 44 of Set 2 | mataura
# Processing Record 45 of Set 2 | husavik
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | coquimbo
# Processing Record 49 of Set 2 | springdale
# Processing Record 50 of Set 2 | bengkulu
# Processing Record 1 of Set 3 | bossier city
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | zhezkazgan
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | rieti
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | nelspruit
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | jiayuguan
# Processing Record 13 of Set 3 | omsukchan
# Processing Record 14 of Set 3 | mogadishu
# Processing Record 15 of Set 3 | methoni
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | teya
# Processing Record 18 of Set 3 | taltal
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | biak
# Processing Record 21 of Set 3 | makakilo city
# Processing Record 22 of Set 3 | iqaluit
# Processing Record 23 of Set 3 | ormara
# Processing Record 24 of Set 3 | ekhabi
# Processing Record 25 of Set 3 | uyuni
# Processing Record 26 of Set 3 | saint george
# Processing Record 27 of Set 3 | pavlohrad
# Processing Record 28 of Set 3 | khatanga
# Processing Record 29 of Set 3 | new norfolk
# Processing Record 30 of Set 3 | marau
# Processing Record 31 of Set 3 | hofn
# Processing Record 32 of Set 3 | saldanha
# Processing Record 33 of Set 3 | tabou
# Processing Record 34 of Set 3 | butaritari
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | kanchipuram
# Processing Record 37 of Set 3 | jamestown
# Processing Record 38 of Set 3 | acapulco
# Processing Record 39 of Set 3 | cidreira
# Processing Record 40 of Set 3 | male
# Processing Record 41 of Set 3 | tessalit
# Processing Record 42 of Set 3 | tazmalt
# Processing Record 43 of Set 3 | tuktoyaktuk
# Processing Record 44 of Set 3 | takaka
# Processing Record 45 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 3 | ixtapa
# Processing Record 47 of Set 3 | parrsboro
# Processing Record 48 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | balkanabat
# Processing Record 1 of Set 4 | asau
# Processing Record 2 of Set 4 | chokurdakh
# Processing Record 3 of Set 4 | beringovskiy
# Processing Record 4 of Set 4 | mindelo
# Processing Record 5 of Set 4 | yellowknife
# Processing Record 6 of Set 4 | mundi
# Processing Record 7 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | dingle
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | matoury
# Processing Record 12 of Set 4 | longyearbyen
# Processing Record 13 of Set 4 | ambovombe
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | vostok
# Processing Record 16 of Set 4 | vila velha
# Processing Record 17 of Set 4 | zar
# Processing Record 18 of Set 4 | bereda
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | east london
# Processing Record 22 of Set 4 | salimbalan
# Processing Record 23 of Set 4 | turukhansk
# Processing Record 24 of Set 4 | sinnar
# Processing Record 25 of Set 4 | palmas bellas
# Processing Record 26 of Set 4 | easton
# Processing Record 27 of Set 4 | ponta do sol
# Processing Record 28 of Set 4 | ekpoma
# Processing Record 29 of Set 4 | tonshayevo
# Processing Record 30 of Set 4 | vila do maio
# Processing Record 31 of Set 4 | leningradskiy
# Processing Record 32 of Set 4 | maarianhamina
# Processing Record 33 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 4 | trang
# Processing Record 35 of Set 4 | chuy
# Processing Record 36 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 4 | okhotsk
# Processing Record 38 of Set 4 | san antero
# Processing Record 39 of Set 4 | touros
# Processing Record 40 of Set 4 | port lincoln
# Processing Record 41 of Set 4 | mwinilunga
# Processing Record 42 of Set 4 | tyrma
# Processing Record 43 of Set 4 | salyan
# Processing Record 44 of Set 4 | archidona
# Processing Record 45 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 4 | padang
# Processing Record 47 of Set 4 | dunedin
# Processing Record 48 of Set 4 | klaksvik
# Processing Record 49 of Set 4 | alofi
# Processing Record 50 of Set 4 | bathsheba
# Processing Record 1 of Set 5 | santa lucia
# Processing Record 2 of Set 5 | bandarbeyla
# Processing Record 3 of Set 5 | carnarvon
# Processing Record 4 of Set 5 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 5 of Set 5 | diamantino
# Processing Record 6 of Set 5 | quang ngai
# Processing Record 7 of Set 5 | kindu
# Processing Record 8 of Set 5 | masunga
# Processing Record 9 of Set 5 | morondava
# Processing Record 10 of Set 5 | yar-sale
# Processing Record 11 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 12 of Set 5 | ancud
# Processing Record 13 of Set 5 | novosysoyevka
# Processing Record 14 of Set 5 | pangoa
# Processing Record 15 of Set 5 | santiago del estero
# Processing Record 16 of Set 5 | tynda
# Processing Record 17 of Set 5 | russell
# Processing Record 18 of Set 5 | dwarka
# Processing Record 19 of Set 5 | teruel
# Processing Record 20 of Set 5 | zuwarah
# Processing Record 21 of Set 5 | aden
# Processing Record 22 of Set 5 | villa rica
# Processing Record 23 of Set 5 | marabba
# Processing Record 24 of Set 5 | esperance
# Processing Record 25 of Set 5 | san angelo
# Processing Record 26 of Set 5 | kushiro
# Processing Record 27 of Set 5 | sisian
# Processing Record 28 of Set 5 | alugan
# Processing Record 29 of Set 5 | geraldton
# Processing Record 30 of Set 5 | rio gallegos
# Processing Record 31 of Set 5 | prestea
# Processing Record 32 of Set 5 | maldonado
# Processing Record 33 of Set 5 | cap malheureux
# Processing Record 34 of Set 5 | mezen
# Processing Record 35 of Set 5 | kavaratti
# Processing Record 36 of Set 5 | carmo do paranaiba
# Processing Record 37 of Set 5 | chabahar
# Processing Record 38 of Set 5 | the valley
# Processing Record 39 of Set 5 | muros
# Processing Record 40 of Set 5 | lielvarde
# Processing Record 41 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 42 of Set 5 | el rosario
# Processing Record 43 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 5 | saint-joseph
# Processing Record 47 of Set 5 | ahipara
# Processing Record 48 of Set 5 | salalah
# Processing Record 49 of Set 5 | gonbad-e qabus
# Processing Record 50 of Set 5 | coolum beach
# Processing Record 1 of Set 6 | thinadhoo
# Processing Record 2 of Set 6 | coihaique
# Processing Record 3 of Set 6 | lavrentiya
# Processing Record 4 of Set 6 | codrington
# Processing Record 5 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 6 of Set 6 | muisne
# Processing Record 7 of Set 6 | tuatapere
# Processing Record 8 of Set 6 | dalvik
# Processing Record 9 of Set 6 | strezhevoy
# Processing Record 10 of Set 6 | canyon
# Processing Record 11 of Set 6 | tabas
# Processing Record 12 of Set 6 | villarrobledo
# Processing Record 13 of Set 6 | quatre cocos
# Processing Record 14 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 6 | srednekolymsk
# Processing Record 16 of Set 6 | hailar
# Processing Record 17 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 6 | puerto colombia
# Processing Record 19 of Set 6 | zhangzhou
# Processing Record 20 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 6 | batemans bay
# Processing Record 22 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 23 of Set 6 | prachuap khiri khan
# Processing Record 24 of Set 6 | cozumel
# Processing Record 25 of Set 6 | pisco
# Processing Record 26 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 6 | san cristobal
# Processing Record 28 of Set 6 | kyshtovka
# Processing Record 29 of Set 6 | ewa beach
# Processing Record 30 of Set 6 | bairiki
# Processing Record 31 of Set 6 | vardo
# Processing Record 32 of Set 6 | baoning
# Processing Record 33 of Set 6 | mahon
# Processing Record 34 of Set 6 | chaman
# Processing Record 35 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 36 of Set 6 | kaeo
# Processing Record 37 of Set 6 | bandar-e lengeh
# Processing Record 38 of Set 6 | kahului
# Processing Record 39 of Set 6 | adrar
# Processing Record 40 of Set 6 | petaluma
# Processing Record 41 of Set 6 | torbay
# Processing Record 42 of Set 6 | bacolod
# Processing Record 43 of Set 6 | rawson
# Processing Record 44 of Set 6 | yerbogachen
# Processing Record 45 of Set 6 | nenjiang
# Processing Record 46 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 6 | dakar
# Processing Record 49 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 50 of Set 6 | gamba
# Processing Record 1 of Set 7 | santa rita do passa quatro
# Processing Record 2 of Set 7 | aswan
# Processing Record 3 of Set 7 | maslova pristan
# Processing Record 4 of Set 7 | togur
# Processing Record 5 of Set 7 | xichang
# Processing Record 6 of Set 7 | lata
# Processing Record 7 of Set 7 | fatehabad
# Processing Record 8 of Set 7 | olinda
# Processing Record 9 of Set 7 | pahrump
# Processing Record 10 of Set 7 | fram
# Processing Record 11 of Set 7 | ikongo
# Processing Record 12 of Set 7 | alice springs
# Processing Record 13 of Set 7 | nefteyugansk
# Processing Record 14 of Set 7 | sechura
# Processing Record 15 of Set 7 | atar
# Processing Record 16 of Set 7 | rio grande
# Processing Record 17 of Set 7 | masumbwe
# Processing Record 18 of Set 7 | ketchikan
# Processing Record 19 of Set 7 | yulara
# Processing Record 20 of Set 7 | buta
# Processing Record 21 of Set 7 | katsuura
# Processing Record 22 of Set 7 | port hedland
# Processing Record 23 of Set 7 | camana
# Processing Record 24 of Set 7 | komsomolskiy
# Processing Record 25 of Set 7 | strelka
# Processing Record 26 of Set 7 | atambua
# Processing Record 27 of Set 7 | kankaanpaa
# Processing Record 28 of Set 7 | san patricio
# Processing Record 29 of Set 7 | whyalla
# Processing Record 30 of Set 7 | abu kamal
# Processing Record 31 of Set 7 | muzhi
# Processing Record 32 of Set 7 | sfantu gheorghe
# Processing Record 33 of Set 7 | sao filipe
# Processing Record 34 of Set 7 | ayer itam
# City not found. Skipping...
# Processing Record 35 of Set 7 | hatillo
# Processing Record 36 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 7 | pataskala
# Processing Record 38 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 39 of Set 7 | bonavista
# Processing Record 40 of Set 7 | lyman
# Processing Record 41 of Set 7 | pekalongan
# Processing Record 42 of Set 7 | turayf
# Processing Record 43 of Set 7 | tautira
# Processing Record 44 of Set 7 | high level
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 7 | soyo
# Processing Record 47 of Set 7 | mount isa
# Processing Record 48 of Set 7 | la ronge
# Processing Record 49 of Set 7 | cabo san lucas
# Processing Record 50 of Set 7 | pimentel
# Processing Record 1 of Set 8 | les cayes
# Processing Record 2 of Set 8 | arboledas
# Processing Record 3 of Set 8 | krasnoarmeysk
# Processing Record 4 of Set 8 | mubi
# Processing Record 5 of Set 8 | nelson bay
# Processing Record 6 of Set 8 | ostrovnoy
# Processing Record 7 of Set 8 | paita
# Processing Record 8 of Set 8 | constitucion
# Processing Record 9 of Set 8 | chiredzi
# Processing Record 10 of Set 8 | candelaria
# Processing Record 11 of Set 8 | sao jose da coroa grande
# Processing Record 12 of Set 8 | uribia
# Processing Record 13 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 8 | marang
# Processing Record 15 of Set 8 | san juan
# Processing Record 16 of Set 8 | batagay
# Processing Record 17 of Set 8 | porkhov
# Processing Record 18 of Set 8 | vilyuysk
# Processing Record 19 of Set 8 | lagoa
# Processing Record 20 of Set 8 | odweyne
# Processing Record 21 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 8 | pilar
# Processing Record 23 of Set 8 | naze
# Processing Record 24 of Set 8 | walla walla
# Processing Record 25 of Set 8 | badulla
# Processing Record 26 of Set 8 | kulhudhuffushi
# Processing Record 27 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 28 of Set 8 | inta
# Processing Record 29 of Set 8 | tshane
# Processing Record 30 of Set 8 | bilma
# Processing Record 31 of Set 8 | morada nova
# Processing Record 32 of Set 8 | klyuchi
# Processing Record 33 of Set 8 | buraydah
# Processing Record 34 of Set 8 | uray
# Processing Record 35 of Set 8 | bangassou
# Processing Record 36 of Set 8 | pevek
# Processing Record 37 of Set 8 | freeport
# Processing Record 38 of Set 8 | eydhafushi
# Processing Record 39 of Set 8 | rabo de peixe
# Processing Record 40 of Set 8 | kidal
# Processing Record 41 of Set 8 | northam
# Processing Record 42 of Set 8 | laizhou
# Processing Record 43 of Set 8 | nanakuli
# Processing Record 44 of Set 8 | ous
# Processing Record 45 of Set 8 | ust-maya
# Processing Record 46 of Set 8 | cedar city
# Processing Record 47 of Set 8 | cangzhou
# Processing Record 48 of Set 8 | hasaki
# Processing Record 49 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 8 | vaitape
# Processing Record 1 of Set 9 | fairbanks
# Processing Record 2 of Set 9 | tommot
# Processing Record 3 of Set 9 | lompoc
# Processing Record 4 of Set 9 | tilichiki
# Processing Record 5 of Set 9 | novoagansk
# Processing Record 6 of Set 9 | yenagoa
# Processing Record 7 of Set 9 | palmer
# Processing Record 8 of Set 9 | madarounfa
# Processing Record 9 of Set 9 | sao joao da barra
# Processing Record 10 of Set 9 | ati
# Processing Record 11 of Set 9 | nhamunda
# Processing Record 12 of Set 9 | makasar
# Processing Record 13 of Set 9 | rocha
# Processing Record 14 of Set 9 | pahalgam
# Processing Record 15 of Set 9 | san policarpo
# Processing Record 16 of Set 9 | surin
# Processing Record 17 of Set 9 | mananjary
# Processing Record 18 of Set 9 | jasper
# Processing Record 19 of Set 9 | hambantota
# Processing Record 20 of Set 9 | tefe
# Processing Record 21 of Set 9 | sitka
# Processing Record 22 of Set 9 | harper
# Processing Record 23 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 9 | mastic beach
# Processing Record 25 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 26 of Set 9 | fengrun
# Processing Record 27 of Set 9 | axim
# Processing Record 28 of Set 9 | abancay
# Processing Record 29 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 9 | kenai
# Processing Record 31 of Set 9 | tura
# Processing Record 32 of Set 9 | pedernales
# Processing Record 33 of Set 9 | ambon
# Processing Record 34 of Set 9 | deputatskiy
# Processing Record 35 of Set 9 | changji
# Processing Record 36 of Set 9 | arcachon
# Processing Record 37 of Set 9 | ferkessedougou
# Processing Record 38 of Set 9 | shache
# Processing Record 39 of Set 9 | tazovskiy
# Processing Record 40 of Set 9 | hornepayne
# Processing Record 41 of Set 9 | belmonte
# Processing Record 42 of Set 9 | colborne
# Processing Record 43 of Set 9 | sorland
# Processing Record 44 of Set 9 | noumea
# Processing Record 45 of Set 9 | tibu
# Processing Record 46 of Set 9 | nyurba
# Processing Record 47 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 9 | mount vernon
# Processing Record 49 of Set 9 | grindavik
# Processing Record 50 of Set 9 | nemuro
# Processing Record 1 of Set 10 | mongo
# Processing Record 2 of Set 10 | necochea
# Processing Record 3 of Set 10 | wanlaweyn
# Processing Record 4 of Set 10 | dibaya
# City not found. Skipping...
# Processing Record 5 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 6 of Set 10 | port hawkesbury
# Processing Record 7 of Set 10 | chingirlau
# Processing Record 8 of Set 10 | bristol
# Processing Record 9 of Set 10 | newport
# Processing Record 10 of Set 10 | port elizabeth
# Processing Record 11 of Set 10 | salinopolis
# Processing Record 12 of Set 10 | pacifica
# Processing Record 13 of Set 10 | ambilobe
# Processing Record 14 of Set 10 | saint pete beach
# Processing Record 15 of Set 10 | camacari
# Processing Record 16 of Set 10 | paamiut
# Processing Record 17 of Set 10 | jacqueville
# Processing Record 18 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 10 | kuruman
# Processing Record 20 of Set 10 | shirokiy
# Processing Record 21 of Set 10 | pangkalanbuun
# Processing Record 22 of Set 10 | half moon bay
# Processing Record 23 of Set 10 | brodokalmak
# Processing Record 24 of Set 10 | algiers
# Processing Record 25 of Set 10 | nogliki
# Processing Record 26 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 10 | haines junction
# Processing Record 28 of Set 10 | dali
# Processing Record 29 of Set 10 | inirida
# Processing Record 30 of Set 10 | mahina
# Processing Record 31 of Set 10 | cacoal
# Processing Record 32 of Set 10 | victor harbor
# Processing Record 33 of Set 10 | englewood
# Processing Record 34 of Set 10 | chernyshevskiy
# Processing Record 35 of Set 10 | hobyo
# Processing Record 36 of Set 10 | dhekiajuli
# Processing Record 37 of Set 10 | smithers
# Processing Record 38 of Set 10 | shellbrook
# Processing Record 39 of Set 10 | pemangkat
# Processing Record 40 of Set 10 | midland
# Processing Record 41 of Set 10 | naryan-mar
# Processing Record 42 of Set 10 | marsh harbour
# Processing Record 43 of Set 10 | hay river
# Processing Record 44 of Set 10 | camacha
# Processing Record 45 of Set 10 | talnakh
# Processing Record 46 of Set 10 | kirkenes
# Processing Record 47 of Set 10 | gainesville
# Processing Record 48 of Set 10 | sola
# Processing Record 49 of Set 10 | koslan
# Processing Record 50 of Set 10 | berlevag
# Processing Record 1 of Set 11 | dolores
# Processing Record 2 of Set 11 | ankang
# Processing Record 3 of Set 11 | dehloran
# Processing Record 4 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 5 of Set 11 | evensk
# Processing Record 6 of Set 11 | samarai
# Processing Record 7 of Set 11 | puerto barrios
# Processing Record 8 of Set 11 | banikoara
# Processing Record 9 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 10 of Set 11 | conde
# Processing Record 11 of Set 11 | bonfim
# Processing Record 12 of Set 11 | sistranda
# Processing Record 13 of Set 11 | pangnirtung
# Processing Record 14 of Set 11 | mareeba
# Processing Record 15 of Set 11 | talaya
# Processing Record 16 of Set 11 | portobelo
# Processing Record 17 of Set 11 | lorengau
# Processing Record 18 of Set 11 | punta alta
# Processing Record 19 of Set 11 | saint anthony
# Processing Record 20 of Set 11 | la asuncion
# Processing Record 21 of Set 11 | conselheiro pena
# Processing Record 22 of Set 11 | port blair
# Processing Record 23 of Set 11 | baherden
# Processing Record 24 of Set 11 | manokwari
# Processing Record 25 of Set 11 | jalu
# Processing Record 26 of Set 11 | seoul
# Processing Record 27 of Set 11 | ribeira brava
# Processing Record 28 of Set 11 | hazorasp
# Processing Record 29 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 11 | san javier
# Processing Record 31 of Set 11 | kapoeta
# Processing Record 32 of Set 11 | tual
# Processing Record 33 of Set 11 | imbituba
# Processing Record 34 of Set 11 | skiros
# City not found. Skipping...
# Processing Record 35 of Set 11 | hundorp
# Processing Record 36 of Set 11 | juarez
# Processing Record 37 of Set 11 | carmarthen
# Processing Record 38 of Set 11 | innisfail
# Processing Record 39 of Set 11 | san carlos de bariloche
# Processing Record 40 of Set 11 | ingham
# Processing Record 41 of Set 11 | flin flon
# Processing Record 42 of Set 11 | buturlinovka
# Processing Record 43 of Set 11 | portland
# Processing Record 44 of Set 11 | visnes
# Processing Record 45 of Set 11 | westport
# Processing Record 46 of Set 11 | troitsko-pechorsk
# Processing Record 47 of Set 11 | lyubashivka
# Processing Record 48 of Set 11 | nan
# Processing Record 49 of Set 11 | srivardhan
# Processing Record 50 of Set 11 | niny
# Processing Record 1 of Set 12 | poum
# Processing Record 2 of Set 12 | svetlogorsk
# Processing Record 3 of Set 12 | teguldet
# Processing Record 4 of Set 12 | gat
# Processing Record 5 of Set 12 | greeneville
# Processing Record 6 of Set 12 | zhangye
# Processing Record 7 of Set 12 | kisangani
# Processing Record 8 of Set 12 | dosso
# Processing Record 9 of Set 12 | coahuayana
# Processing Record 10 of Set 12 | scarborough
# Processing Record 11 of Set 12 | labuhan
# Processing Record 12 of Set 12 | duluth
# Processing Record 13 of Set 12 | carbondale
# Processing Record 14 of Set 12 | eyl
# Processing Record 15 of Set 12 | sungairaya
# Processing Record 16 of Set 12 | meulaboh
# Processing Record 17 of Set 12 | gunnedah
# Processing Record 18 of Set 12 | hualmay
# Processing Record 19 of Set 12 | fallon
# Processing Record 20 of Set 12 | mpophomeni
# Processing Record 21 of Set 12 | manoel urbano
# Processing Record 22 of Set 12 | ulladulla
# Processing Record 23 of Set 12 | peleduy
# Processing Record 24 of Set 12 | punto fijo
# Processing Record 25 of Set 12 | terney
# Processing Record 26 of Set 12 | alyangula
# Processing Record 27 of Set 12 | peru
# Processing Record 28 of Set 12 | kirakira
# Processing Record 29 of Set 12 | port macquarie
# Processing Record 30 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 12 | mayumba
# Processing Record 32 of Set 12 | souillac
# Processing Record 33 of Set 12 | kailua
# Processing Record 34 of Set 12 | pandhurna
# Processing Record 35 of Set 12 | vrangel
# Processing Record 36 of Set 12 | virginia beach
# Processing Record 37 of Set 12 | vao
# Processing Record 38 of Set 12 | zabolottya
# City not found. Skipping...
# Processing Record 39 of Set 12 | mbekenyera
# Processing Record 40 of Set 12 | ayan
# Processing Record 41 of Set 12 | syamzha
# Processing Record 42 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 43 of Set 12 | slavyanka
# Processing Record 44 of Set 12 | tramore
# Processing Record 45 of Set 12 | pacific grove
# Processing Record 46 of Set 12 | manaure
# Processing Record 47 of Set 12 | porto santo
# Processing Record 48 of Set 12 | copiapo
# Processing Record 49 of Set 12 | verkhnyaya inta
# Processing Record 50 of Set 12 | catamarca
# Processing Record 1 of Set 13 | helong
# Processing Record 2 of Set 13 | hare bay
# Processing Record 3 of Set 13 | bokoro
# Processing Record 4 of Set 13 | kargasok
# Processing Record 5 of Set 13 | serra branca
# Processing Record 6 of Set 13 | deniliquin
# Processing Record 7 of Set 13 | gonaives
# Processing Record 8 of Set 13 | mahanoro
# Processing Record 9 of Set 13 | wiang sa
# Processing Record 10 of Set 13 | vicuna
# Processing Record 11 of Set 13 | sibu
# Processing Record 12 of Set 13 | riyadh
# Processing Record 13 of Set 13 | narayangarh
# Processing Record 14 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 13 | masuda
# Processing Record 16 of Set 13 | olafsvik
# Processing Record 17 of Set 13 | santiago
# Processing Record 18 of Set 13 | baijiantan
# Processing Record 19 of Set 13 | isangel
# Processing Record 20 of Set 13 | itaituba
# Processing Record 21 of Set 13 | kloulklubed
# Processing Record 22 of Set 13 | santa isabel do rio negro
# Processing Record 23 of Set 13 | palauig
# Processing Record 24 of Set 13 | karachi
# Processing Record 25 of Set 13 | marakkanam
# Processing Record 26 of Set 13 | contamana
# Processing Record 27 of Set 13 | saint-remi
# Processing Record 28 of Set 13 | churapcha
# Processing Record 29 of Set 13 | port-gentil
# Processing Record 30 of Set 13 | barrhead
# Processing Record 31 of Set 13 | nanga eboko
# Processing Record 32 of Set 13 | berezovyy
# Processing Record 33 of Set 13 | cockburn town
# Processing Record 34 of Set 13 | hoi an
# Processing Record 35 of Set 13 | barranca
# Processing Record 36 of Set 13 | kjollefjord
# Processing Record 37 of Set 13 | dzaoudzi
# Processing Record 38 of Set 13 | santa cecilia
# Processing Record 39 of Set 13 | swan river
# Processing Record 40 of Set 13 | vestmanna
# Processing Record 41 of Set 13 | betsiamites
# Processing Record 42 of Set 13 | palu
# Processing Record 43 of Set 13 | kyzyl-suu
# Processing Record 44 of Set 13 | pakaur
# Processing Record 45 of Set 13 | hlubocky
# Processing Record 46 of Set 13 | linhares
# Processing Record 47 of Set 13 | vieste
# Processing Record 48 of Set 13 | rassvet
# Processing Record 49 of Set 13 | ontario
# Processing Record 50 of Set 13 | los llanos de aridane
# Processing Record 1 of Set 14 | bunumbu
# Processing Record 2 of Set 14 | saint-pierre
# Processing Record 3 of Set 14 | matara
# Processing Record 4 of Set 14 | cah ab
# City not found. Skipping...
# Processing Record 5 of Set 14 | trairi
# Processing Record 6 of Set 14 | vila franca do campo
# Processing Record 7 of Set 14 | mnogovershinnyy
# Processing Record 8 of Set 14 | inhambane
# Processing Record 9 of Set 14 | chicama
# Processing Record 10 of Set 14 | batsfjord
# Processing Record 11 of Set 14 | luchegorsk
# Processing Record 12 of Set 14 | labrea
# Processing Record 13 of Set 14 | iracoubo
# Processing Record 14 of Set 14 | glogow
# Processing Record 15 of Set 14 | te anau
# Processing Record 16 of Set 14 | brigantine
# Processing Record 17 of Set 14 | itoman
# Processing Record 18 of Set 14 | kramat
# Processing Record 19 of Set 14 | grajau
# Processing Record 20 of Set 14 | kroya
# Processing Record 21 of Set 14 | narsipatnam
# Processing Record 22 of Set 14 | santiago de cao
# Processing Record 23 of Set 14 | assiniboia
# Processing Record 24 of Set 14 | calabozo
# Processing Record 25 of Set 14 | namibe
# Processing Record 26 of Set 14 | nome
# Processing Record 27 of Set 14 | barcelona
# Processing Record 28 of Set 14 | namatanai
# Processing Record 29 of Set 14 | caravelas
# Processing Record 30 of Set 14 | acarau
# Processing Record 31 of Set 14 | lanxi
# Processing Record 32 of Set 14 | the pas
# Processing Record 33 of Set 14 | awbari
# Processing Record 34 of Set 14 | hollister
# Processing Record 35 of Set 14 | businga
# Processing Record 36 of Set 14 | burica
# City not found. Skipping...
# Processing Record 37 of Set 14 | sehithwa
# Processing Record 38 of Set 14 | ust-ishim
# Processing Record 39 of Set 14 | mumford
# Processing Record 40 of Set 14 | keflavik
# Processing Record 41 of Set 14 | kemijarvi
# Processing Record 42 of Set 14 | rumonge
# Processing Record 43 of Set 14 | sandnessjoen
# Processing Record 44 of Set 14 | riverton
# Processing Record 45 of Set 14 | denpasar
# Processing Record 46 of Set 14 | ust-ilimsk
# Processing Record 47 of Set 14 | phuket
# Processing Record 48 of Set 14 | nabire
# Processing Record 49 of Set 14 | uvinza
# Processing Record 50 of Set 14 | rock sound
# Processing Record 1 of Set 15 | synya
# Processing Record 2 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 3 of Set 15 | shakawe
# Processing Record 4 of Set 15 | mbandaka
# Processing Record 5 of Set 15 | gloversville
# Processing Record 6 of Set 15 | crotone
# Processing Record 7 of Set 15 | nuuk
# Processing Record 8 of Set 15 | dunda
# Processing Record 9 of Set 15 | aktau
# Processing Record 10 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 11 of Set 15 | kampot
# Processing Record 12 of Set 15 | agvali
# Processing Record 13 of Set 15 | litovko
# Processing Record 14 of Set 15 | bilecik
# Processing Record 15 of Set 15 | celestun
# Processing Record 16 of Set 15 | belaya gora
# Processing Record 17 of Set 15 | shiyan
# Processing Record 18 of Set 15 | caluquembe
# Processing Record 19 of Set 15 | mayakonda
# Processing Record 20 of Set 15 | bagdarin
# Processing Record 21 of Set 15 | boralday
# Processing Record 22 of Set 15 | itigi
# Processing Record 23 of Set 15 | valleyview
# Processing Record 24 of Set 15 | ojinaga
# Processing Record 25 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 26 of Set 15 | buchanan
# Processing Record 27 of Set 15 | tomatlan
# Processing Record 28 of Set 15 | gao
# Processing Record 29 of Set 15 | shestakovo
# Processing Record 30 of Set 15 | luorong
# Processing Record 31 of Set 15 | puerto carreno
# Processing Record 32 of Set 15 | guerrero negro
# Processing Record 33 of Set 15 | nuevo progreso
# Processing Record 34 of Set 15 | cayenne
# Processing Record 35 of Set 15 | krasnoselkup
# Processing Record 36 of Set 15 | castilho
# Processing Record 37 of Set 15 | priamurskiy
# Processing Record 38 of Set 15 | lake havasu city
# Processing Record 39 of Set 15 | ugra
# Processing Record 40 of Set 15 | havelock
# Processing Record 41 of Set 15 | koundara
# Processing Record 42 of Set 15 | sakaiminato
# Processing Record 43 of Set 15 | kortkeros
# Processing Record 44 of Set 15 | bermeo
# Processing Record 45 of Set 15 | bubaque
# Processing Record 46 of Set 15 | lasa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df.reindex(columns = new_column_order)

city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Gambela      ET   8.2500   34.5833     75.34        76          92
# 1        Upernavik      GL  72.7868  -56.1549     -2.36        85         100
# 2   Vestmannaeyjar      IS  63.4427  -20.2734     42.64        70          23
# 3  Arraial Do Cabo      BR -22.9661  -42.0278     73.53        67           2
# 4          College      US  64.8569 -147.8028     39.18        25           0
#
#    Wind Speed Current Description
# 0        4.54     overcast clouds
# 1       13.62     overcast clouds
# 2        5.99          few clouds
# 3       13.15           clear sky
# 4        9.22           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
